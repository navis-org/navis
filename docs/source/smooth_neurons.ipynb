# %% [raw]
# Smoothing neurons
# *****************
#
# This example will demonstrate how to smooth a neuron using :func:`pymaid.smooth_neuron`.

# %%
import pymaid
import matplotlib.pyplot as plt

rm = pymaid.CatmaidInstance('server_url','http_user','http_pw','token')

n = pymaid.get_neurons(16)

fig, ax = n.plot2d(connectors=False, linewidth=1)

plt.show()

# %% [raw]
# Let's smooth that neuron:

# %%
smoothed = pymaid.smooth_neuron(n, inplace=False)

# %%
fig, ax = smoothed.plot2d(connectors=False, linewidth=1)

plt.show()

# %% [raw]
# Most obviously, the two big spikes have become smaller. But if you look closely, you'll find that everything has become smoother. This should also show in the cable length:

# %%
print('Old cable: {:.2f} um'.format(n.cable_length))
print('New cable: {:.2f} um'.format(smoothed.cable_length))
# Out:
# Old cable: 2866.10 um
# New cable: 2987.53 um

# %% [raw]
# You can increase the smoothing :func:`pymaid.smooth_neuron`:

# %%
more_smoothed = pymaid.smooth_neuron(n, 50, inplace=False)

fig, ax = more_smoothed.plot2d(connectors=False, linewidth=1)

plt.show()

# %% [raw]
# There is a limit to how far you should increase the smoothing factor:

# %%
too_smoothed = pymaid.smooth_neuron(n, 500, inplace=False)

fig, ax = too_smoothed.plot2d(connectors=False, linewidth=1)

plt.show()

# %% [raw]
# Generally speaking smoothing factors between 2-20 should be safe.
#
# This is the relevant function:
#
# .. autosummary::
#
#     pymaid.smooth_neuron
