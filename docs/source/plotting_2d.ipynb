# %% [raw]
# 2D Plotting
# ***********
#
# Pymaid has functions for 2D and 3D plotting of neurons. Here, we will focus on **2D** plots.
#
# Why this is actually 2.5D
# =========================
# Pymaid uses `matplotlib <https://matplotlib.org/>`_ to generate 2D plots. ``matplotlib``'s capabilities when it comes to 3D data are limited. Unfortunately, neurons are 3 dimensional structures so please bear with me for this quick *disclaimer* before we get started:
#
# The main problem (which matplotlib inherits from the way vector graphics work) is the limited z (depth) ordering: e.g. a line can either be behind or in front of another line but they can never intertwine. Matplotlib tries to simulate proper z-order but results vary. Concretely, that means that a neuron e.g. might appear entirely in front of another neuron while in reality they intertwine. The more busy your plot and the more neurons intertwine, the more likely this is to happen.
#
# There are solutions to that issue which we will discuss below. As a rule of thumb: *if you plot only single neurons, all neurons have the same colour or you know that they don't intertwine, you are safe*.
#
# *Why even bother with 2D?* The main reason is that pymaid's 2D plots produce *vector graphics* - which generally look better than pixelated 3D plots.
#
#
# Plotting neurons
# ================
# Neuron objects, :class:`~pymaid.CatmaidNeuron` and :class:`~pymaid.CatmaidNeuronList`, as well as nblast results (:class:`~pymaid.rmaid.nbl_results`) have built-in methods that act as wrappers for :func:`pymaid.plot3d` or :func:`pymaid.plot2d`:

# %%
import pymaid
import matplotlib.pyplot as plt

# Connect to CATMAID
rm = pymaid.CatmaidInstance('www.your.catmaid-server.org',
                            'HTTP_USER' ,
                            'HTTP_PASSWORD',
                            'TOKEN')

# Get two neurons
nl = pymaid.get_neurons(['57311', '27295'])

# Plot using defaults
fig, ax = nl.plot2d()
plt.show()

# %% [raw]
# You would get the same result using :func:`pymaid.plot2d` directly:

# %%
fig, ax = pymaid.plot2d(nl)
plt.show()

# %% [raw]
# You can tweak a whole bunch of parameters. Have a look at :func:`pymaid.plot2d`!

# %%
fig, ax = pymaid.plot2d(nl,
                        color={'57311': 'k', '27295': 'y'},
                        connectors=False,
                        linewidth=1.5)
plt.show()

# %% [raw]
# By default, :func:`pymaid.plot2d` uses a simple 2D method for plotting in which **the order of items determines the layering** z-order:

# %%
# Reverse order in CatmaidNeuronList
nl_rev = nl[::-1]
fig, ax = pymaid.plot2d(nl_rev,
                        color={'57311': 'k', '27295': 'y'},
                        connectors=False,
                        linewidth=1.5)
plt.show()

# %% [raw]
# Plotting in 2.5D
# ================
#
# Above plots are plain, simple 2D. This means that the z-order is determined by the order of neurons passed to the function. It also means that we can't change the perspective.
# Fortunately, :func:`pymaid.plot2d` enables us to change that behaviour by adjusting the ``method`` parameter:

# %%
# Plot using matplotlib's 2.5D capabilities
fig, ax = nl.plot2d(method='3d',
                    connectors=False,
                    linewidth=1.5)

# Change from default frontal view to lateral view by changing the azimuth
ax.azim = 0

# Zoom in a bit
ax.dist = 6

plt.show()

# %%
fig, ax = nl.plot2d(method='3d',
                    connectors=False,
                    linewidth=1.5)

# Change from default frontal view to top view by changing the elevation
ax.elev = 90

# Zoom in a bit
ax.dist = 6

plt.show()

# %% [raw]
# We can use these transformations to render small animations:

# %%
fig, ax = nl.plot2d(method='3d_complex',
                    connectors=False,
                    linewidth=1.5)

for i in range(0,360,5):
   # Change rotation
   ax.azim = i
   # Save each incremental rotation as frame
   plt.savefig('_frames/frame_{0}.png'.format(i), dpi=200)
    
plt.clf()

# %% [raw]
# Above code gives you 360 frames that you can put together into a video using e.g. `Fiji <https://fiji.sc/>`_.
#
# .. image:: rotation.gif
#    :width: 400pt
#
#
# Plotting complex scenes
# =======================
# You may have noticed that we used ``method='3d_complex'`` in above example. This breaks down neurons into smaller objects (as opposed to each neuron = 1 object) which allows matplotlib to more faithfully simulate z-order at the cost of more computations required. You should use this whenever correct perspective matters!

# %%
nl2 = pymaid.get_neurons('annotation:glomerulus DA1')

fig, ax = nl2.plot2d(method='3d_complex',
                     connectors=False,
                     linewidth=1.5)

ax.dist = 6

plt.show()

# %% [raw]
# Plotting volumes
# ================
#
# Plotting volumes is pretty straight forward. You can either combine neurons and volume(s) in a single call...

# %%
# Retrieve volume
lh = pymaid.get_volume('LH_R')

# Set color and alpha
lh.color = (0, 1, 0, .1)

# Plot
fig, ax = pymaid.plot2d([nl ,lh], method='3d_complex', linewidth=1.5, connectors=False)
ax.dist = 6

plt.show()

# %% [raw]
# ... or add them to an existing figure:

# %%
# Plot neurons first
fig, ax = nl.plot2d(method='3d_complex', linewidth=1.5, connectors=True)

# Add volume on existing ax
_ = pymaid.plot2d(lh, method='3d_complex', ax=ax)

ax.dist = 6

plt.show()
