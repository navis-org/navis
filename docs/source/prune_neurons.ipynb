# %% [raw]
# Pruning neurons
# ***************
#
# This example will demonstrate how to prune neurons.

# %%
import pymaid
import matplotlib.pyplot as plt

rm = pymaid.CatmaidInstance('server_url','http_user','http_pw','token')

n = pymaid.get_neurons(16)

fig, ax = n.plot2d(connectors=False, linewidth=1)

plt.show()

# %% [raw]
# Pruning by Strahler Index
# -------------------------
#
# First, we will learn how to use :func:`pymaid.prune_by_strahler` to prune a neuron to its main branches using `Strahler index <https://en.wikipedia.org/wiki/Strahler_number>`_:

# %%
# Keep the two highest Strahler orders
backbone = pymaid.prune_by_strahler(n, to_prune=-2, inplace=False)

fig, ax = backbone.plot2d(connectors=False, linewidth=1)
plt.show()

# %% [raw]
# Conversely, you can keep only the higher Strahler order branches:

# %%
# Keep the two highest Strahler orders
terminals = pymaid.prune_by_strahler(n, to_prune=range(3,100), inplace=False)

fig, ax = terminals.plot2d(connectors=False, linewidth=1)
plt.show()

# %% [raw]
# Like for many other functions, there are shorthands for :func:`pymaid.prune_by_strahler` in ``CatmaidNeuron/Lists``:

# %%
backbone = n.prune_by_strahler(to_prune=-2, inplace=False)

# %% [raw]
# Pruning by tags
# ---------------
#
# For this example, let's assume that while you traced a neuron, you had to add tiny, "fake" branches to reach e.g. a synapses. If you tagged these branches using the ``not a branch`` treenode tag, we can use it to remove those branches:

# %%
no_fake_branches = pymaid.remove_tagged_branches(n, 'not a branch', how='segment', inplace=False)
print('Number of terminals before pruning: {}'.format(n.n_end_nodes))
print('Number of terminals after pruning: {}'.format(no_fake_branches.n_end_nodes))
# Out:
# Number of terminals before pruning: 823
# Number of terminals after pruning: 814

# %% [raw]
# The neuron we are working with here apparently has only a very few ``not a branch`` branches (or they haven't been annotated). Removing these branches might sound unnecessary but you should keep in mind that they will affect e.g. the Strahler order.
#
# Another use case for this function would be to prune the neuron down to the microtubule containing backbone using the ``microtubules end`` tag:

# %%
mt_only = pymaid.remove_tagged_branches(n, 'microtubules end', how='distal', inplace=False)

# %% [raw]
# These are the relevant functions:
#
# .. autosummary::
#
#     pymaid.prune_by_strahler
#     pymaid.strahler_index
#     pymaid.remove_tagged_branches
